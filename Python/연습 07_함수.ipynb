# %%
### 일반 형태
def add(a, b):
    x = a
    y = b
    print(x)
    print(y)
    result = x + y
    return result

# %%
print(add(a=10, b=5))
# Out:
# 10
# 5
# 15

# %%
### return이 없는 형태
def add(a,b):
    res = a+b
    print(f'result = {res}')

# %%
add(10,5)
# Out:
# result = 15

# %%
mylist = [1,3,5]
res = mylist.append(10)
print(res) # 할당하면 안되는 것
# Out:
# None
